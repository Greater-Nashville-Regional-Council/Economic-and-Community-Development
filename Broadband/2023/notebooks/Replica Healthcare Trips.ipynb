# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from functools import reduce
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 150)
from functools import reduce
pd.options.mode.chained_assignment = None  # default='warn'
from warnings import simplefilter
simplefilter(action="ignore", category=pd.errors.PerformanceWarning)

# %%
data = pd.read_csv('../data/replica_spring2023weekday_healthcaretripstodavidsonco.csv')

# %%
data.head()
# Out:
#       origin_cty           activity_id
# 0  Out of Region  13193175413320866345
# 1  Out of Region  10387273645672472857
# 2  Out of Region   6828611952482604841
# 3  Out of Region  16494357324005527278
# 4  Out of Region   4617198653606872395

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36604 entries, 0 to 36603
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   origin_cty   36604 non-null  object
#  1   activity_id  36604 non-null  uint64
# dtypes: object(1), uint64(1)
# memory usage: 572.1+ KB

# %%
data = data.drop_duplicates().reset_index(drop = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36604 entries, 0 to 36603
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   origin_cty   36604 non-null  object
#  1   activity_id  36604 non-null  uint64
# dtypes: object(1), uint64(1)
# memory usage: 572.1+ KB

# %%
trips = data.groupby('origin_cty')['activity_id'].nunique().reset_index()

# %%
trips
# Out:
#                  origin_cty  activity_id
# 0        Bedford County, TN            4
# 1        Bledsoe County, TN            1
# 2       Cheatham County, TN          435
# 3         Coffee County, TN            5
# 4        Colbert County, AL            4
# 5       Crockett County, TN            1
# 6       Davidson County, TN        25733
# 7         DeKalb County, TN            2
# 8        Decatur County, TN            2
# 9        Dickson County, TN          405
# 10      Franklin County, TN            2
# 11         Giles County, TN            1
# 12        Grundy County, TN            1
# 13      Hamilton County, TN            3
# 14       Haywood County, TN            1
# 15     Henderson County, TN            2
# 16         Henry County, TN            3
# 17       Hickman County, TN            5
# 18       Houston County, TN           12
# 19     Humphreys County, TN           36
# 20  Independence County, AR            1
# 21     Jefferson County, AL            4
# ...

# %%
trips.columns = ['origin_cty', 'unique_trips']

# %%
trips.head()
# Out:
#             origin_cty  unique_trips
# 0   Bedford County, TN             4
# 1   Bledsoe County, TN             1
# 2  Cheatham County, TN           435
# 3    Coffee County, TN             5
# 4   Colbert County, AL             4

# %%
trips.to_csv('../data/healthcare_replica_output.csv', index = False)
